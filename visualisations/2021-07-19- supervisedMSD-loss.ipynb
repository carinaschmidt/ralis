# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
log_001 = '/mnt/qb/baumgartner/cschmidt77_data/ckpt_seg_acdc/2021-07-18-supervised_msdHeart0.001/log.txt'
log_01 = '/mnt/qb/baumgartner/cschmidt77_data/ckpt_seg_acdc/2021-07-18-supervised_msdHeart0.01/log.txt'
log_05 = '/mnt/qb/baumgartner/cschmidt77_data/ckpt_seg_acdc/2021-07-18-supervised_msdHeart0.05/log.txt'

# %%
log_001
# Out:
# '/mnt/qb/baumgartner/cschmidt77_data/ckpt_seg_acdc/2021-07-18-supervised_msdHeart0.001/log.txt'

# %%
df_001 = pd.read_csv(log_001, delimiter = "\t")
df_01 = pd.read_csv(log_01, delimiter = "\t")
df_05 = pd.read_csv(log_05, delimiter = "\t")

# %%
df_001
# Out:
#      Epoch  Learning Rate  Train Loss  (deprecated)  Valid Loss  Train Acc.  \
# 0      0.0       0.001000    0.138956           0.0    0.034847    0.989351
# 1      1.0       0.000998    0.029616           0.0    0.014859    0.993637
# 2      2.0       0.000996    0.022700           0.0    0.013495    0.993637
# 3      3.0       0.000994    0.020966           0.0    0.012788    0.993637
# 4      4.0       0.000992    0.019741           0.0    0.012010    0.993637
# ..     ...            ...         ...           ...         ...         ...
# 473  473.0       0.000388    0.003617           0.0    0.002488    0.998543
# 474  474.0       0.000387    0.003598           0.0    0.002646    0.998543
# 475  475.0       0.000386    0.003621           0.0    0.002500    0.998532
# 476  476.0       0.000386    0.003513           0.0    0.002495    0.998576
# 477  477.0       0.000385    0.003586           0.0    0.002525    0.998535
#
# ...

# %%
train_loss_001 = df_001[['Train Loss']]
val_loss_001 = df_001[['Valid Loss']]

# %%
plt.figure(figsize=(10,10))
plt.plot(df_001[['Train Loss']])
plt.plot(df_001[['Valid Loss']])
plt.title('Train and Validation loss lr 0.001')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(df_01[['Train Loss']])
plt.plot(df_01[['Valid Loss']])
plt.title('Train and Validation loss lr 0.01')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(df_05[['Train Loss']])
plt.plot(df_05[['Valid Loss']])
plt.title('Train and Validation loss lr 0.05')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# Load train / val loss curves for ACDC training with pre-trained

# %%
train_acdc_on_msd_pretrained = '/mnt/qb/baumgartner/cschmidt77_data/ckpt_seg_acdc/2021-07-19-train_acdc_MSDPretrained_budget_608_lr_0.01_seed_123/ep0_log.txt'

# %%
df_train_acdc = pd.read_csv(train_acdc_on_msd_pretrained , delimiter = "\t")

# %%
df_train_acdc
# Out:
#     Epoch  Learning Rate  Train Loss  (deprecated)  Valid Loss  Train Acc.  \
# 0    48.0       0.009960    0.078702           0.0    0.283048    0.976923
# 1    48.0       0.009920    0.189900           0.0    0.716545    0.932427
# 2    48.0       0.009881    0.029568           0.0    0.654306    0.990157
# 3    48.0       0.009841    0.190306           0.0    0.863054    0.927865
# 4    48.0       0.009802    0.026996           0.0    0.384598    0.990228
# 5    48.0       0.009763    0.070168           0.0    0.717178    0.970799
# 6    48.0       0.009724    0.138716           0.0    0.455089    0.943758
# 7    48.0       0.009685    0.075632           0.0    0.679965    0.966414
# 8    48.0       0.009646    0.336518           0.0    0.461478    0.885283
# 9    48.0       0.009608    0.167218           0.0    0.187793    0.943375
# 10   48.0       0.009569    0.096526           0.0    0.313248    0.959233
# ...

# %%
train_loss_acdc = df_train_acdc[['Train Loss']]
val_loss_acdc = df_train_acdc[['Valid Loss']]

# %%
plt.plot(train_loss_acdc)
plt.plot(val_loss_acdc)
plt.title('Train and Validation loss lr 0.05')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
log_001 = '/mnt/qb/baumgartner/cschmidt77_data/ckpt_seg_acdc/2021-07-22-supervised_msdHeart_valLossTest0.001/log.txt'
log_01 = '/mnt/qb/baumgartner/cschmidt77_data/ckpt_seg_acdc/2021-07-22-supervised_msdHeart_valLossTest0.01/log.txt'
log_05 = '/mnt/qb/baumgartner/cschmidt77_data/ckpt_seg_acdc/2021-07-22-supervised_msdHeart_valLossTest0.05/log.txt'

# %%
df_001 = pd.read_csv(log_001, delimiter = "\t")
df_01 = pd.read_csv(log_01, delimiter = "\t")
df_05 = pd.read_csv(log_05, delimiter = "\t")

# %%
train_loss_001 = df_001[['Train Loss']]
val_loss_001 = df_001[['Valid Loss']]
plt.figure(figsize=(10,10))
plt.plot(df_001[['Train Loss']])
plt.plot(df_001[['Valid Loss']])
plt.title('Train and Validation loss lr 0.001')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
train_loss_01 = df_01[['Train Loss']]
val_loss_01 = df_01[['Valid Loss']]
plt.figure(figsize=(10,10))
plt.plot(df_01[['Train Loss']])
plt.plot(df_01[['Valid Loss']])
plt.title('Train and Validation loss lr 0.01')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
train_loss_05 = df_05[['Train Loss']]
val_loss_05 = df_05[['Valid Loss']]
plt.figure(figsize=(10,10))
plt.plot(df_05[['Train Loss']])
plt.plot(df_05[['Valid Loss']])
plt.title('Train and Validation loss lr 0.05')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
