# %%
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image
import matplotlib.image as mpimg

# %%
def rc_params():
    plt.rc('text', usetex=True)
    plt.rc('font', **{'family': 'serif', 'sans-serif': ['lmodern'], 'size': 12})
    plt.rc('axes', **{'titlesize': 14, 'labelsize': 18})
    plt.rc('xtick', **{'labelsize': 18})
    plt.rc('ytick', **{'labelsize': 18})
    plt.rc('legend', **{'fontsize': 18})
    plt.rc('figure', **{'figsize': (12,7)})

# %%
rc_params()
# RALIS
fig, ax = plt.subplots(1,2,figsize=(8,4))
#plt.rcParams['font.size'] = '8'

ax[0].imshow(mpimg.imread('/home/carina/boxplots_AL_structures_Exp5ACDC_budget_1184/ACDC_slice.png')) #mask
ax[0].set_title("MRI Slice")
ax[0].axis('off')

ax[1].set_title("MRI Slice with Segmentation")
ax[1].imshow(mpimg.imread('/home/carina/boxplots_AL_structures_Exp5ACDC_budget_1184/ACDC_gt.png')) #image
ax[1].axis('off')

# ax[2].set_title("Worst MYO DSC (RALIS)")
# ax[2].imshow(mpimg.imread('/home/carina/boxplots_AL_structures_Exp5ACDC_budget_1184/thesis-best-worst-median/RALIS_worst_pat094_slice.png')) #mask
# ax[2].axis('off')

plt.savefig('/home/carina/Desktop/ACDC-example.pdf', bbox_inches='tight')

# %%
rc_params()
# RALIS
fig, ax = plt.subplots(3,1,figsize=(9,9))
#plt.rcParams['font.size'] = '8'

ax[0].imshow(mpimg.imread('/home/carina/boxplots_AL_structures_Exp5ACDC_budget_1184/thesis-best-worst-median/RALIS_best_pat075.png')) #mask
ax[0].set_title("Best MYO DSC (RALIS)")
ax[0].axis('off')

# ax[1].set_title("Median MYO DSC (RALIS)")
# ax[1].imshow(mpimg.imread('/home/carina/boxplots_AL_structures_Exp5ACDC_budget_1184/thesis-best-worst-median/RALIS_median_pat097_slice.png')) #image
# ax[1].axis('off')

# ax[2].set_title("Worst MYO DSC (RALIS)")
# ax[2].imshow(mpimg.imread('/home/carina/boxplots_AL_structures_Exp5ACDC_budget_1184/thesis-best-worst-median/RALIS_worst_pat094_slice.png')) #mask
# ax[2].axis('off')

plt.savefig('/home/carina/Desktop/Best-Median-Worst/R.pdf', bbox_inches='tight')

# %%
rc_params()
# Random
fig, ax = plt.subplots(3,1,figsize=(9,9))
plt.rcParams['font.size'] = '8'

ax[0].imshow(mpimg.imread('/home/carina/boxplots_AL_structures_Exp5ACDC_budget_1184/thesis-best-worst-median/RANDOM_best_pat013.png')) #mask
ax[0].set_title("Best MYO DSC (Random)")
ax[0].axis('off')

ax[1].set_title("Median MYO DSC (Random)")
ax[1].imshow(mpimg.imread('/home/carina/boxplots_AL_structures_Exp5ACDC_budget_1184/thesis-best-worst-median/RANDOM_median_pat097_slice.png')) #image
ax[1].axis('off')

ax[2].set_title("Worst MYO DSC (Random)")
ax[2].imshow(mpimg.imread('/home/carina/boxplots_AL_structures_Exp5ACDC_budget_1184/thesis-best-worst-median/RANDOM_worst_pat094_slice.png')) #mask
ax[2].axis('off')

plt.savefig('/home/carina/Desktop/Best-Median-Worst/Random_best_median_worst.pdf', bbox_inches='tight')
